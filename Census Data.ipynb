# %% [markdown]
# # Census Dataset

# %%
import pandas as pd
# import matplotlib.pyplot as plt
import seaborn as sns

data=pd.read_csv(r"C:\Users\Rebecca\Downloads\Census Dataset India.csv")
data.tail(10)
# Out:
#      District_code                   State_name              District_name  \
# 630            631                   TAMIL NADU                Krishnagiri
# 631            632                   TAMIL NADU                 Coimbatore
# 632            633                   TAMIL NADU                   Tiruppur
# 633            634                  PONDICHERRY                      Yanam
# 634            635                  PONDICHERRY                PONDICHERRY
# 635            636                  PONDICHERRY                       Mahe
# 636            637                  PONDICHERRY                   Karaikal
# 637            638  ANDAMAN AND NICOBAR ISLANDS                   Nicobars
# 638            639  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman
# 639            640  ANDAMAN AND NICOBAR ISLANDS              South Andaman
#
#      Population     Male   Female  Literate  Workers  Male_Workers  \
# 630     1879809   960232   919577   1187958   877779        561634
# ...

# %% [markdown]
# # Data Cleaning

# %%
#checking for missing values
data.isnull()#no missing data

#checking data types
data.dtypes
# Out:
# District_code            int64
# State_name              object
# District_name           object
# Population               int64
# Male                     int64
# Female                   int64
# Literate                 int64
# Workers                  int64
# Male_Workers             int64
# Female_Workers           int64
# Cultivator_Workers       int64
# Agricultural_Workers     int64
# Household_Workers        int64
# Hindus                   int64
# Muslims                  int64
# Christians               int64
# Sikhs                    int64
# Buddhists                int64
# Jains                    int64
# Secondary_Education      int64
# Higher_Education         int64
# Graduate_Education       int64
# Age_Group_0_29           int64
# Age_Group_30_49          int64
# Age_Group_50             int64
# dtype: object

# %% [markdown]
# # 1. Which districts have the highest and lowest population?

# %%
#highest population distict #MAHARASHTRA         Thane
print(data[data.Population == data.Population.max()])

#lowest population district #ARUNACHAL PRADESH  Dibang Valley
print(data[data.Population == data.Population.min()])
# Out:
#      District_code   State_name District_name  Population     Male   Female  \
# 516            517  MAHARASHTRA         Thane    11060148  5865078  5195070
#
#      Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 516   8227161  4492767       3363123         1129644  ...      280700  39149
#
#      Buddhists   Jains  Secondary_Education  Higher_Education  \
# 516     449617  172052              1751284           1080597
#
#      Graduate_Education  Age_Group_0_29  Age_Group_30_49  Age_Group_50
# 516              961719         6184519          3241888       1579921
#
# [1 rows x 25 columns]
#      District_code         State_name  District_name  Population  Male  \
# 256            257  ARUNACHAL PRADESH  Dibang Valley        8004  4414
#
#      Female  Literate  Workers  Male_Workers  Female_Workers  ...  Christians  \
# 256    3590      4436     3555          2228            1327  ...         223
#
# ...

# %% [markdown]
# # 2. Which district had the highest number of males and females?

# %%
print(data[data.Male == data.Male.max()])
# MAHARASHTRA         Thane
print(data[data.Female == data.Female.max()])
# Out:
#      District_code   State_name District_name  Population     Male   Female  \
# 516            517  MAHARASHTRA         Thane    11060148  5865078  5195070
#
#      Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 516   8227161  4492767       3363123         1129644  ...      280700  39149
#
#      Buddhists   Jains  Secondary_Education  Higher_Education  \
# 516     449617  172052              1751284           1080597
#
#      Graduate_Education  Age_Group_0_29  Age_Group_30_49  Age_Group_50
# 516              961719         6184519          3241888       1579921
#
# [1 rows x 25 columns]
#      District_code   State_name District_name  Population     Male   Female  \
# 516            517  MAHARASHTRA         Thane    11060148  5865078  5195070
#
#      Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 516   8227161  4492767       3363123         1129644  ...      280700  39149
#
# ...

# %% [markdown]
# # 3. Which district had the lowest number of males and females

# %%
print(data[data.Male == data.Male.min()])
      
#ARUNACHAL PRADESH  Dibang Valley
print(data[data.Female == data.Female.min()])
# Out:
#      District_code         State_name  District_name  Population  Male  \
# 256            257  ARUNACHAL PRADESH  Dibang Valley        8004  4414
#
#      Female  Literate  Workers  Male_Workers  Female_Workers  ...  Christians  \
# 256    3590      4436     3555          2228            1327  ...         223
#
#      Sikhs  Buddhists  Jains  Secondary_Education  Higher_Education  \
# 256      7        126      2                  809               656
#
#      Graduate_Education  Age_Group_0_29  Age_Group_30_49  Age_Group_50
# 256                 356            5113             2088           786
#
# [1 rows x 25 columns]
#      District_code         State_name  District_name  Population  Male  \
# 256            257  ARUNACHAL PRADESH  Dibang Valley        8004  4414
#
#      Female  Literate  Workers  Male_Workers  Female_Workers  ...  Christians  \
# 256    3590      4436     3555          2228            1327  ...         223
#
# ...

# %% [markdown]
# # 4. Which region had the most literate workers?

# %%
print(data[data.Literate == data.Literate.max()])
# Out:
#      District_code   State_name District_name  Population     Male   Female  \
# 516            517  MAHARASHTRA         Thane    11060148  5865078  5195070
#
#      Literate  Workers  Male_Workers  Female_Workers  ...  Christians  Sikhs  \
# 516   8227161  4492767       3363123         1129644  ...      280700  39149
#
#      Buddhists   Jains  Secondary_Education  Higher_Education  \
# 516     449617  172052              1751284           1080597
#
#      Graduate_Education  Age_Group_0_29  Age_Group_30_49  Age_Group_50
# 516              961719         6184519          3241888       1579921
#
# [1 rows x 25 columns]

# %% [markdown]
# # 5. Which age group had the highest number of cultivators,agricultural                and household workers

# %%
#data.columns
print(data[data.groupby('Cultivator_Workers').agg({'Age_Group_0_29':['mean', 'min', 'max']})])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 2
#       1 #data.columns
# ----> 2 print(data[data.groupby('Cultivator_Workers').agg({'Age_Group_0_29':['mean', 'min', 'max']})])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3748, in DataFrame.__getitem__(self, key)
#    3746 # Do we have a (boolean) DataFrame?
#    3747 if isinstance(key, DataFrame):
# -> 3748     return self.where(key)
#    3750 # Do we have a (boolean) 1d indexer?
#    3751 if com.is_bool_indexer(key):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:11527, in DataFrame.where(self, cond, other, inplace, axis, level)
#   11518 def where(
#   11519     self,
#   11520     cond,
#    (...)
#   11525     level: Level = None,
#   11526 ) -> DataFrame | None:
# > 11527     return super().where(
#   11528         cond,
#   11529         other,
# ...

# %% [markdown]
# # 6. Which gender lived longest?

# %% [markdown]
# # 7. Which type of workers lived longest?
